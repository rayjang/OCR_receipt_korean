# %%
#from PIL import Image
import pytesseract
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./ocr.jpg',0)

et, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
cv2.THRESH_BINARY,15,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,3,1)

titles = ['Original','Global','Mean','Gaussian']
images = [img,th1,th2,th3]

#cv2.imshow(th1)
plt.imshow(th3)
cv2.imwrite('./mean.jpg', th3)
# Out:
# True

# %%
#img = Image.open('./rotated.jpg')
img = cv2.imread('./rotated.jpg',0)
img = Image.open('./rotated.jpg')
plt.imshow(img)
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_sobel = cv2.Sobel(img,cv2.CV_8U,1,0)#same as default,None,3,1,0,cv2.BORDER_DEFAULT)
plt.imshow(img_sobel)
img_threshold = cv2.threshold(img_sobel,0,255,cv2.THRESH_OTSU+cv2.THRESH_BINARY)
plt.imshow(img_threshold)
element = cv2.getStructuringElement(cv2.MORPH_RECT,ele_size)
img_threshold = cv2.morphologyEx(img_threshold[1],cv2.MORPH_CLOSE,element)
plt.imshow(img_threshold)
print(pytesseract.image_to_string(th3, lang='kor+eng'))

#print(pytesseract.image_to_string(Image.open('./rotated.jpg'), lang='kor+eng'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a509d31d356d> in <module>
#       3 img = Image.open('./rotated.jpg')
#       4 plt.imshow(img)
# ----> 5 img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       6 img_sobel = cv2.Sobel(img,cv2.CV_8U,1,0)#same as default,None,3,1,0,cv2.BORDER_DEFAULT)
#       7 plt.imshow(img_sobel)
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %%
print(pytesseract.image_to_string(Image.open('./ocr.jpg'), lang='kor'))
# Out:
# 린 미 트
# 사 입 지 빈 호 :222-08-8294 사 업 자 빈 호 :222-06-52:
# 주 소 : 강 원 도 태 백 시 황 지 동 200-26 감왼도 태 백 시 밉자동 200-28
# 대 표 ; 이 정 환 전 화 번 호 :(033)553-0788 이 정 띈 편 회 버 회 | 네 제 198950(08.
# 006101 판 매 자 : 김 용 남
#
#
#
# -- 2015-11
# 애좁임】 2015-11-8 훌 력 일 시 : 2015-11-28
# 못 016110 조 뺏덱 기 초 소 방 시 설 섬 치 (2017.? 4 한 )
# * 주 택 기초소 시 설 설 지 (2017.2.4 한 ) 랑는 이
# 이 내 로 해 주 세 요 , * 월 수 증 지 참 시 반 품 / 환 물 이 가 능 합 니 다 .
# * 영 수 증 지 참 시 반 품 / 한 불 이 가 능 합 니 다 , 수 보 너 스 카 드 발 급 ( 포 인트 97$
# @보너스캬드빌급(포인트 적 립 ) 후 , 이돕삐 가 아발
#
# 바 코드 "l쩨삐뻬효갱쪄늄뻬 _ 삐 뼈 뼈
